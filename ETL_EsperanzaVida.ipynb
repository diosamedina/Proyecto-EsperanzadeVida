# %%
import wbgapi as wb
import pandas as pd

# %%
paises = ["ATG", "ARG", "BHS", "BRB", "BLZ", "BOL", "BRA", "CAN", "CHL", "COL", "CRI", "CUB", "DMA", "DOM", "ECU", "SLV", "GRD", "GTM", "GUY", "HTI", "HND", "JAM", "MEX", "NIC", "PAN", "PRY", "PER", "KNA", "LCA", "VCT", "SUR", "TTO", "URY", "VEN", "USA"]

# %%
nombres_paises = {
    "ATG": "Antigua y Barbuda",
    "ARG": "Argentina",
    "BHS": "Bahamas",
    "BRB": "Barbados",
    "BLZ": "Belice",
    "BOL": "Bolivia",
    "BRA": "Brasil",
    "CAN": "Canadá",
    "CHL": "Chile",
    "COL": "Colombia",
    "CRI": "Costa Rica",
    "CUB": "Cuba",
    "DMA": "Dominica",
    "DOM": "República Dominicana",
    "ECU": "Ecuador",
    "SLV": "El Salvador",
    "GRD": "Granada",
    "GTM": "Guatemala",
    "GUY": "Guyana",
    "HTI": "Haití",
    "HND": "Honduras",
    "JAM": "Jamaica",
    "MEX": "México",
    "NIC": "Nicaragua",
    "PAN": "Panamá",
    "PRY": "Paraguay",
    "PER": "Perú",
    "KNA": "San Cristóbal y Nieves",
    "LCA": "Santa Lucía",
    "VCT": "San Vicente y las Granadinas",
    "SUR": "Surinam",
    "TTO": "Trinidad y Tobago",
    "URY": "Uruguay",
    "VEN": "Venezuela",
    "USA": "Estados Unidos de América"
}

# %%
df_esperanza_mujeres = wb.data.DataFrame(['SP.DYN.LE00.FE.IN'], paises, mrv=30).reset_index() #Reseteamos indices
df_esperanza_hombres = wb.data.DataFrame(['SP.DYN.LE00.MA.IN'], paises, mrv=30).reset_index() #Reseteamos indices
df_esperanza_general = wb.data.DataFrame(['SP.DYN.LE00.IN'], paises, mrv=30).reset_index() #Reseteamos indices
df_cobertura_servicios = wb.data.DataFrame(['SH.UHC.SRVS.CV.XD'], paises, mrv=30).reset_index() #Reseteamos indices
df_gastos_salud = wb.data.DataFrame(['SH.XPD.CHEX.PC.CD'], paises, mrv=30).reset_index() #Reseteamos indices
df_indice_gini = wb.data.DataFrame(['SI.POV.GINI'], paises, mrv=30).reset_index() #Reseteamos indices
df_personas_debajo_50 = wb.data.DataFrame(['SI.DST.50MD'], paises, mrv=30).reset_index() #Reseteamos indices
df_pobreza_multidimensional = wb.data.DataFrame(['SI.POV.MDIM'], paises, mrv=30).reset_index() #Reseteamos indices
df_homicidios = wb.data.DataFrame(['VC.IHR.PSRC.P5'], paises, mrv=30).reset_index() #Reseteamos indices
df_desempleo = wb.data.DataFrame(['SL.UEM.TOTL.ZS'], paises, mrv=31).reset_index() #Reseteamos indices
df_gasto_educacion = wb.data.DataFrame(['NY.ADJ.AEDU.CD'], paises, mrv=30).reset_index() #Reseteamos indices
df_nivel_educativo = wb.data.DataFrame(['SE.TER.CUAT.BA.ZS'], paises, mrv=30).reset_index() #Reseteamos indices
df_pib = wb.data.DataFrame(['NY.GDP.MKTP.CD'], paises, mrv=30).reset_index() #Reseteamos indices
df_tasa_nacimientos = wb.data.DataFrame(['SP.DYN.CBRT.IN'], paises, mrv=30).reset_index() #Reseteamos indices
df_tasa_mortalidad = wb.data.DataFrame(['SP.DYN.CDRT.IN'], paises, mrv=30).reset_index() #Reseteamos indices
df_tasa_mortalidad_infantil = wb.data.DataFrame(['SP.DYN.IMRT.IN'], paises, mrv=30).reset_index() #Reseteamos indices

# %%
df_esperanza_mujeres = df_esperanza_mujeres.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_esperanza_mujeres.insert(1, 'Nombre_Pais', df_esperanza_mujeres['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_esperanza_hombres = df_esperanza_hombres.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_esperanza_hombres.insert(1, 'Nombre_Pais', df_esperanza_hombres['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_esperanza_general = df_esperanza_general.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_esperanza_general.insert(1, 'Nombre_Pais', df_esperanza_general['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_cobertura_servicios = df_cobertura_servicios.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_cobertura_servicios.insert(1, 'Nombre_Pais', df_cobertura_servicios['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_gastos_salud = df_gastos_salud.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_gastos_salud.insert(1, 'Nombre_Pais', df_gastos_salud['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_indice_gini = df_indice_gini.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_indice_gini.insert(1, 'Nombre_Pais', df_indice_gini['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_personas_debajo_50 = df_personas_debajo_50.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_personas_debajo_50.insert(1, 'Nombre_Pais', df_personas_debajo_50['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_pobreza_multidimensional = df_pobreza_multidimensional.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_pobreza_multidimensional.insert(1, 'Nombre_Pais', df_pobreza_multidimensional['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_homicidios = df_homicidios.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_homicidios.insert(1, 'Nombre_Pais', df_homicidios['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_desempleo = df_desempleo.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_desempleo.insert(1, 'Nombre_Pais', df_desempleo['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_gasto_educacion = df_gasto_educacion.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_gasto_educacion.insert(1, 'Nombre_Pais', df_gasto_educacion['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_nivel_educativo = df_nivel_educativo.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_nivel_educativo.insert(1, 'Nombre_Pais', df_nivel_educativo['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_pib = df_pib.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_pib.insert(1, 'Nombre_Pais', df_pib['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_tasa_nacimientos = df_tasa_nacimientos.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_tasa_nacimientos.insert(1, 'Nombre_Pais', df_tasa_nacimientos['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_tasa_mortalidad = df_tasa_mortalidad.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_tasa_mortalidad.insert(1, 'Nombre_Pais', df_tasa_mortalidad['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

df_tasa_mortalidad_infantil = df_tasa_mortalidad_infantil.rename(columns={"economy": 'Codigo_Pais'}) # Renombramos la columna
df_tasa_mortalidad_infantil.insert(1, 'Nombre_Pais', df_tasa_mortalidad_infantil['Codigo_Pais'].map(nombres_paises)) # Mapeamos para asignar a cada código el nombre del pais completo

# %% [markdown]
# creamos un diccionario para mapear codigos

# %%
indicadores = {
    'SP.DYN.LE00.FE.IN': 'Esperanza de vida al nacer, mujeres (años)',
    'SP.DYN.LE00.IN': 'Esperanza de vida al nacer, total (años)',
    'SP.DYN.LE00.MA.IN': 'Esperanza de vida al nacer, hombres (años)',
    'SH.UHC.SRVS.CV.XD': 'Índice de cobertura de servicios UHC',
    'SH.XPD.CHEX.PC.CD': 'Gasto corriente en salud per cápita (US$ corrientes)',
    'SI.POV.GINI': 'Índice de Gini',
    'SI.DST.50MD': 'Proporción de personas que viven por debajo del 50% del ingreso medio (%)',
    'SI.POV.MDIM': 'Tasa de recuento de la pobreza multidimensional (% de la población total)',
    'VC.IHR.PSRC.P5': 'Homicidios dolosos (por cada 100.000 habitantes)',
    'SL.UEM.TOTL.ZS': 'Desempleo, total (% de la población activa total) (estimación modelada de la OIT)',
    'NY.ADJ.AEDU.CD': 'Ahorro ajustado: Gasto en educación (US$ a precio ajustado)',
    'SE.TER.CUAT.BA.ZS': 'Nivel educativo, al menos secundaria superior completa, población de más de 25 años, total (%) (acumulativo)',
    'NY.GDP.MKTP.CD': 'PIB',
    'SP.DYN.CBRT.IN': 'Tasa de nacimientos',
    'SP.DYN.CDRT.IN': 'Tasa de mortalidad, cruda',
    'SP.DYN.IMRT.IN': 'Tasa de mortalidad infantil (por 1000 nacimientos vivos'
}

# %%
dataframes = [
    df_esperanza_mujeres,
    df_esperanza_hombres,
    df_esperanza_general,
    df_cobertura_servicios,
    df_gastos_salud,
    df_indice_gini,
    df_personas_debajo_50,
    df_pobreza_multidimensional,
    df_homicidios,
    df_desempleo,
    df_gasto_educacion,
    df_nivel_educativo,
    df_pib,
    df_tasa_nacimientos,
    df_tasa_mortalidad,
    df_tasa_mortalidad_infantil
]

# %%
codigos = [
    'SP.DYN.LE00.FE.IN',
    'SP.DYN.LE00.MA.IN',
    'SP.DYN.LE00.IN',
    'SH.UHC.SRVS.CV.XD',
    'SH.XPD.CHEX.PC.CD',
    'SI.POV.GINI',
    'SI.DST.50MD',
    'SI.POV.MDIM',
    'VC.IHR.PSRC.P5',
    'SL.UEM.TOTL.ZS',
    'NY.ADJ.AEDU.CD',
    'SE.TER.CUAT.BA.ZS',
    'NY.GDP.MKTP.CD',
    'SP.DYN.CBRT.IN',
    'SP.DYN.CDRT.IN',
    'SP.DYN.IMRT.IN'
]

# %%
for df, codigo in zip(dataframes, codigos): # Generamos un for para crear la columna en cada df con el codigo de la serie
    # indicador = indicadores[codigo]
    if "Codigo_Serie" not in df.columns:
        df.insert(2, "Codigo_Serie", [codigo] * len(df))

# %%
df_esperanza_mujeres.insert(3, 'Nombre_Serie', df_esperanza_mujeres['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_esperanza_hombres.insert(3, 'Nombre_Serie', df_esperanza_hombres['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_esperanza_general.insert(3, 'Nombre_Serie', df_esperanza_general['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_cobertura_servicios.insert(3, 'Nombre_Serie', df_cobertura_servicios['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_gastos_salud.insert(3, 'Nombre_Serie', df_gastos_salud['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_indice_gini.insert(3, 'Nombre_Serie', df_indice_gini['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_personas_debajo_50.insert(3, 'Nombre_Serie', df_personas_debajo_50['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_pobreza_multidimensional.insert(3, 'Nombre_Serie', df_pobreza_multidimensional['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_homicidios.insert(3, 'Nombre_Serie', df_homicidios['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_desempleo.insert(3, 'Nombre_Serie', df_desempleo['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_gasto_educacion.insert(3, 'Nombre_Serie', df_gasto_educacion['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_nivel_educativo.insert(3, 'Nombre_Serie', df_nivel_educativo['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_pib.insert(3, 'Nombre_Serie', df_pib['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_tasa_nacimientos.insert(3, 'Nombre_Serie', df_tasa_nacimientos['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_tasa_mortalidad.insert(3, 'Nombre_Serie', df_tasa_mortalidad['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado
df_tasa_mortalidad_infantil.insert(3, 'Nombre_Serie', df_tasa_mortalidad_infantil['Codigo_Serie'].map(indicadores)) # Mapeamos el codigo a su nombre asociado

# %%
df_esperanza_mujeres.columns = df_esperanza_mujeres.columns[:4].tolist() + df_esperanza_mujeres.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_esperanza_hombres.columns = df_esperanza_hombres.columns[:4].tolist() + df_esperanza_hombres.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_esperanza_general.columns = df_esperanza_general.columns[:4].tolist() + df_esperanza_general.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_cobertura_servicios.columns = df_cobertura_servicios.columns[:4].tolist() + df_cobertura_servicios.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_gastos_salud.columns = df_gastos_salud.columns[:4].tolist() + df_gastos_salud.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_indice_gini.columns = df_indice_gini.columns[:4].tolist() + df_indice_gini.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_personas_debajo_50.columns = df_personas_debajo_50.columns[:4].tolist() + df_personas_debajo_50.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_pobreza_multidimensional.columns = df_pobreza_multidimensional.columns[:4].tolist() + df_pobreza_multidimensional.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_homicidios.columns = df_homicidios.columns[:4].tolist() + df_homicidios.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_desempleo.columns = df_desempleo.columns[:4].tolist() + df_desempleo.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_gasto_educacion.columns = df_gasto_educacion.columns[:4].tolist() + df_gasto_educacion.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_nivel_educativo.columns = df_nivel_educativo.columns[:4].tolist() + df_nivel_educativo.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_pib.columns = df_pib.columns[:4].tolist() + df_pib.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_tasa_nacimientos.columns = df_tasa_nacimientos.columns[:4].tolist() + df_tasa_nacimientos.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_tasa_mortalidad.columns = df_tasa_mortalidad.columns[:4].tolist() + df_tasa_mortalidad.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas
df_tasa_mortalidad_infantil.columns = df_tasa_mortalidad_infantil.columns[:4].tolist() + df_tasa_mortalidad_infantil.columns[4:].str.extract('(\d+)', expand=False).tolist() #Eliminamos el YR de todas los nombres de las columnas

# %%
df_esperanza_mujeres.head()
# Out:
#   Codigo_Pais        Nombre_Pais       Codigo_Serie  \
# 0         ARG          Argentina  SP.DYN.LE00.FE.IN
# 1         ATG  Antigua y Barbuda  SP.DYN.LE00.FE.IN
# 2         BHS            Bahamas  SP.DYN.LE00.FE.IN
# 3         BLZ             Belice  SP.DYN.LE00.FE.IN
# 4         BOL            Bolivia  SP.DYN.LE00.FE.IN
#
#                                  Nombre_Serie    1992    1993    1994    1995  \
# 0  Esperanza de vida al nacer, mujeres (años)  75.719  75.940  76.049  76.243
# 1  Esperanza de vida al nacer, mujeres (años)  75.941  75.835  76.063  76.222
# 2  Esperanza de vida al nacer, mujeres (años)  73.859  73.900  74.025  74.038
# 3  Esperanza de vida al nacer, mujeres (años)  71.462  71.632  72.483  71.981
# 4  Esperanza de vida al nacer, mujeres (años)  59.093  60.044  60.718  61.291
#
#      1996    1997  ...    2012    2013    2014    2015    2016    2017  \
# 0  76.418  76.464  ...  79.953  79.927  80.004  80.188  79.670  80.085
# ...

# %%
df_esperanza_mujeres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          35 non-null     float64
#  5   1993          35 non-null     float64
#  6   1994          35 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
df_esperanza_hombres.head()
# Out:
#   Codigo_Pais        Nombre_Pais       Codigo_Serie  \
# 0         ARG          Argentina  SP.DYN.LE00.MA.IN
# 1         ATG  Antigua y Barbuda  SP.DYN.LE00.MA.IN
# 2         BHS            Bahamas  SP.DYN.LE00.MA.IN
# 3         BLZ             Belice  SP.DYN.LE00.MA.IN
# 4         BOL            Bolivia  SP.DYN.LE00.MA.IN
#
#                                  Nombre_Serie    1992    1993    1994    1995  \
# 0  Esperanza de vida al nacer, hombres (años)  69.095  69.160  70.180  69.950
# 1  Esperanza de vida al nacer, hombres (años)  70.808  71.028  71.029  70.971
# 2  Esperanza de vida al nacer, hombres (años)  67.421  67.371  67.626  67.459
# 3  Esperanza de vida al nacer, hombres (años)  68.614  68.474  68.351  67.978
# 4  Esperanza de vida al nacer, hombres (años)  56.165  56.805  57.295  57.820
#
#      1996    1997  ...    2012    2013    2014    2015    2016    2017  \
# 0  70.123  69.705  ...  72.939  73.011  73.424  73.294  72.933  73.526
# ...

# %%
df_esperanza_hombres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          35 non-null     float64
#  5   1993          35 non-null     float64
#  6   1994          35 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
df_esperanza_general.head()
# Out:
#   Codigo_Pais        Nombre_Pais    Codigo_Serie  \
# 0         ARG          Argentina  SP.DYN.LE00.IN
# 1         ATG  Antigua y Barbuda  SP.DYN.LE00.IN
# 2         BHS            Bahamas  SP.DYN.LE00.IN
# 3         BLZ             Belice  SP.DYN.LE00.IN
# 4         BOL            Bolivia  SP.DYN.LE00.IN
#
#                                Nombre_Serie    1992    1993    1994    1995  \
# 0  Esperanza de vida al nacer, total (años)  72.430  72.565  73.172  73.133
# 1  Esperanza de vida al nacer, total (años)  73.417  73.482  73.591  73.636
# 2  Esperanza de vida al nacer, total (años)  70.668  70.656  70.851  70.763
# 3  Esperanza de vida al nacer, total (años)  69.979  69.988  70.316  69.887
# 4  Esperanza de vida al nacer, total (años)  57.629  58.418  58.989  59.534
#
#      1996    1997  ...    2012    2013    2014    2015    2016    2017  \
# 0  73.307  73.090  ...  76.467  76.491  76.755  76.760  76.308  76.833
# ...

# %%
df_esperanza_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          35 non-null     float64
#  5   1993          35 non-null     float64
#  6   1994          35 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
df_cobertura_servicios.head()
# Out:
#   Codigo_Pais        Nombre_Pais       Codigo_Serie  \
# 0         ARG          Argentina  SH.UHC.SRVS.CV.XD
# 1         ATG  Antigua y Barbuda  SH.UHC.SRVS.CV.XD
# 2         BHS            Bahamas  SH.UHC.SRVS.CV.XD
# 3         BLZ             Belice  SH.UHC.SRVS.CV.XD
# 4         BOL            Bolivia  SH.UHC.SRVS.CV.XD
#
#                            Nombre_Serie  2000  2005  2010  2015  2017  2019
# 0  Índice de cobertura de servicios UHC  68.0  72.0  73.0  74.0  74.0  73.0
# 1  Índice de cobertura de servicios UHC  43.0  65.0  69.0  72.0  72.0  72.0
# 2  Índice de cobertura de servicios UHC  50.0  64.0  64.0  67.0  69.0  70.0
# 3  Índice de cobertura de servicios UHC  46.0  59.0  64.0  64.0  65.0  67.0
# 4  Índice de cobertura de servicios UHC  43.0  49.0  57.0  65.0  65.0  67.0

# %%
df_cobertura_servicios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   2000          35 non-null     float64
#  5   2005          35 non-null     float64
#  6   2010          35 non-null     float64
#  7   2015          35 non-null     float64
#  8   2017          35 non-null     float64
#  9   2019          35 non-null     float64
# dtypes: float64(6), object(4)
# memory usage: 2.9+ KB

# %%
df_gastos_salud.head()
# Out:
#   Codigo_Pais        Nombre_Pais       Codigo_Serie  \
# 0         ARG          Argentina  SH.XPD.CHEX.PC.CD
# 1         ATG  Antigua y Barbuda  SH.XPD.CHEX.PC.CD
# 2         BHS            Bahamas  SH.XPD.CHEX.PC.CD
# 3         BLZ             Belice  SH.XPD.CHEX.PC.CD
# 4         BOL            Bolivia  SH.XPD.CHEX.PC.CD
#
#                                         Nombre_Serie        2000        2001  \
# 0  Gasto corriente en salud per cápita (US$ corri...  704.945923  671.368530
# 1  Gasto corriente en salud per cápita (US$ corri...  519.131165  571.111633
# 2  Gasto corriente en salud per cápita (US$ corri...  945.440308  990.311279
# 3  Gasto corriente en salud per cápita (US$ corri...  136.521317  162.072266
# 4  Gasto corriente en salud per cápita (US$ corri...   42.958511   44.916550
#
#           2002         2003         2004         2005  ...         2012  \
# 0   222.647507   260.982636   310.219940   390.804474  ...  1361.991577
# ...

# %%
df_gastos_salud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   2000          35 non-null     float64
#  5   2001          35 non-null     float64
#  6   2002          35 non-null     float64
#  7   2003          35 non-null     float64
#  8   2004          35 non-null     float64
#  9   2005          35 non-null     float64
#  10  2006          35 non-null     float64
#  11  2007          35 non-null     float64
#  12  2008          35 non-null     float64
#  13  2009          35 non-null     float64
#  14  2010          35 non-null     float64
#  15  2011          35 non-null     float64
#  16  2012          35 non-null     float64
# ...

# %%
df_indice_gini.head()
# Out:
#   Codigo_Pais        Nombre_Pais Codigo_Serie    Nombre_Serie  1992  1993  \
# 0         ARG          Argentina  SI.POV.GINI  Índice de Gini  45.5  44.9
# 1         ATG  Antigua y Barbuda  SI.POV.GINI  Índice de Gini   NaN   NaN
# 2         BHS            Bahamas  SI.POV.GINI  Índice de Gini   NaN   NaN
# 3         BLZ             Belice  SI.POV.GINI  Índice de Gini   NaN  60.3
# 4         BOL            Bolivia  SI.POV.GINI  Índice de Gini   NaN   NaN
#
#    1994  1995  1996  1997  ...  2012  2013  2014  2015  2016  2017  2018  \
# 0  45.9  48.9  49.5  49.1  ...  41.3  40.9  41.6   NaN  42.0  41.1  41.3
# 1   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  60.9   NaN  56.6  60.4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN  58.2  ...  46.6  47.6  47.8  46.7  45.2  44.6  42.6
#
#    2019  2020  2021
# 0  42.9  42.3  42.0
# 1   NaN   NaN   NaN
# ...

# %%
df_indice_gini.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          10 non-null     float64
#  5   1993          8 non-null      float64
#  6   1994          9 non-null      float64
#  7   1995          9 non-null      float64
#  8   1996          13 non-null     float64
#  9   1997          12 non-null     float64
#  10  1998          14 non-null     float64
#  11  1999          16 non-null     float64
#  12  2000          14 non-null     float64
#  13  2001          14 non-null     float64
#  14  2002          15 non-null     float64
#  15  2003          14 non-null     float64
#  16  2004          16 non-null     float64
# ...

# %%
df_personas_debajo_50.head()
# Out:
#   Codigo_Pais        Nombre_Pais Codigo_Serie  \
# 0         ARG          Argentina  SI.DST.50MD
# 1         ATG  Antigua y Barbuda  SI.DST.50MD
# 2         BHS            Bahamas  SI.DST.50MD
# 3         BLZ             Belice  SI.DST.50MD
# 4         BOL            Bolivia  SI.DST.50MD
#
#                                         Nombre_Serie  1992  1993  1994  1995  \
# 0  Proporción de personas que viven por debajo de...  19.6  20.1  20.7  21.2
# 1  Proporción de personas que viven por debajo de...   NaN   NaN   NaN   NaN
# 2  Proporción de personas que viven por debajo de...   NaN   NaN   NaN   NaN
# 3  Proporción de personas que viven por debajo de...   NaN  19.9  19.7   NaN
# 4  Proporción de personas que viven por debajo de...   NaN   NaN   NaN   NaN
#
#    1996  1997  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0  22.5  24.3  ...  20.2  20.2  20.2   NaN  20.7  19.7  20.2  21.2  21.2  18.8
# ...

# %%
df_personas_debajo_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          11 non-null     float64
#  5   1993          8 non-null      float64
#  6   1994          9 non-null      float64
#  7   1995          10 non-null     float64
#  8   1996          13 non-null     float64
#  9   1997          12 non-null     float64
#  10  1998          15 non-null     float64
#  11  1999          17 non-null     float64
#  12  2000          14 non-null     float64
#  13  2001          15 non-null     float64
#  14  2002          16 non-null     float64
#  15  2003          15 non-null     float64
#  16  2004          17 non-null     float64
# ...

# %%
df_pobreza_multidimensional.head()
# Out:
#   Codigo_Pais        Nombre_Pais Codigo_Serie  \
# 0         ARG          Argentina  SI.POV.MDIM
# 1         ATG  Antigua y Barbuda  SI.POV.MDIM
# 2         BHS            Bahamas  SI.POV.MDIM
# 3         BLZ             Belice  SI.POV.MDIM
# 4         BOL            Bolivia  SI.POV.MDIM
#
#                                         Nombre_Serie  2010  2011  2012  2013  \
# 0  Tasa de recuento de la pobreza multidimensiona...   NaN   NaN   NaN   NaN
# 1  Tasa de recuento de la pobreza multidimensiona...   NaN   NaN   NaN   NaN
# 2  Tasa de recuento de la pobreza multidimensiona...   NaN   NaN   NaN   NaN
# 3  Tasa de recuento de la pobreza multidimensiona...   NaN   NaN   NaN   NaN
# 4  Tasa de recuento de la pobreza multidimensiona...   NaN   NaN   NaN   NaN
#
#    2014  2015  2016  2017  2018  2019  2020  2021  2022
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df_pobreza_multidimensional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   2010          5 non-null      float64
#  5   2011          5 non-null      float64
#  6   2012          5 non-null      float64
#  7   2013          6 non-null      float64
#  8   2014          7 non-null      float64
#  9   2015          5 non-null      float64
#  10  2016          7 non-null      float64
#  11  2017          7 non-null      float64
#  12  2018          7 non-null      float64
#  13  2019          6 non-null      float64
#  14  2020          4 non-null      float64
#  15  2021          2 non-null      float64
#  16  2022          1 non-null      float64
# dtypes: float64(13), object(4)
# ...

# %%
df_homicidios.head()
# Out:
#   Codigo_Pais        Nombre_Pais    Codigo_Serie  \
# 0         ARG          Argentina  VC.IHR.PSRC.P5
# 1         ATG  Antigua y Barbuda  VC.IHR.PSRC.P5
# 2         BHS            Bahamas  VC.IHR.PSRC.P5
# 3         BLZ             Belice  VC.IHR.PSRC.P5
# 4         BOL            Bolivia  VC.IHR.PSRC.P5
#
#                                        Nombre_Serie       1992       1993  \
# 0  Homicidios dolosos (por cada 100.000 habitantes)        NaN        NaN
# 1  Homicidios dolosos (por cada 100.000 habitantes)   3.093150   6.075934
# 2  Homicidios dolosos (por cada 100.000 habitantes)  14.540425  12.145840
# 3  Homicidios dolosos (por cada 100.000 habitantes)        NaN        NaN
# 4  Homicidios dolosos (por cada 100.000 habitantes)        NaN        NaN
#
#         1994       1995       1996       1997  ...       2012       2013  \
# 0        NaN        NaN        NaN        NaN  ...   6.311921   7.247288
# 1   7.454676  10.234217   4.298117   1.404149  ...  11.405890        NaN
# ...

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          22 non-null     float64
#  5   1993          21 non-null     float64
#  6   1994          22 non-null     float64
#  7   1995          24 non-null     float64
#  8   1996          22 non-null     float64
#  9   1997          22 non-null     float64
#  10  1998          22 non-null     float64
#  11  1999          23 non-null     float64
#  12  2000          30 non-null     float64
#  13  2001          31 non-null     float64
#  14  2002          31 non-null     float64
#  15  2003          30 non-null     float64
#  16  2004          29 non-null     float64
# ...

# %%
for i in range(len(df_homicidios)):
    minimo = df_homicidios.iloc[i, 4:].min(axis=0)
    df_homicidios.iloc[i] = df_homicidios.iloc[i].fillna(minimo)

# %%
df_desempleo.head()
# Out:
#   Codigo_Pais        Nombre_Pais    Codigo_Serie  \
# 0         ARG          Argentina  SL.UEM.TOTL.ZS
# 1         ATG  Antigua y Barbuda  SL.UEM.TOTL.ZS
# 2         BHS            Bahamas  SL.UEM.TOTL.ZS
# 3         BLZ             Belice  SL.UEM.TOTL.ZS
# 4         BOL            Bolivia  SL.UEM.TOTL.ZS
#
#                                         Nombre_Serie    1992    1993   1994  \
# 0  Desempleo, total (% de la población activa tot...   6.360  10.100  11.76
# 1  Desempleo, total (% de la población activa tot...     NaN     NaN    NaN
# 2  Desempleo, total (% de la población activa tot...  14.810  12.720  13.83
# 3  Desempleo, total (% de la población activa tot...   9.716   9.780  11.10
# 4  Desempleo, total (% de la población activa tot...   3.262   3.089   3.08
#
#      1995   1996   1997  ...   2013   2014    2015    2016  2017    2018  \
# 0  18.800  17.11  14.82  ...   7.10   7.27   7.524   8.109  8.35   9.220
# ...

# %%
df_desempleo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          31 non-null     float64
#  5   1993          31 non-null     float64
#  6   1994          31 non-null     float64
#  7   1995          31 non-null     float64
#  8   1996          31 non-null     float64
#  9   1997          31 non-null     float64
#  10  1998          31 non-null     float64
#  11  1999          31 non-null     float64
#  12  2000          31 non-null     float64
#  13  2001          31 non-null     float64
#  14  2002          31 non-null     float64
#  15  2003          31 non-null     float64
#  16  2004          31 non-null     float64
# ...

# %%
df_desempleo.drop(['2022'], axis=1, inplace=True)  # Eliminamos la columna '2022'

# %%
for i in range(len(df_desempleo)):
    minimo = df_desempleo.iloc[i, 4:].min(axis=0, skipna = True)
    if str(minimo) == 'nan':
        minimo = 0 
    df_desempleo.iloc[i] = df_desempleo.iloc[i].fillna(minimo)

# %%
df_desempleo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          35 non-null     float64
#  5   1993          35 non-null     float64
#  6   1994          35 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
df_gasto_educacion.head()
# Out:
#   Codigo_Pais        Nombre_Pais    Codigo_Serie  \
# 0         ARG          Argentina  NY.ADJ.AEDU.CD
# 1         ATG  Antigua y Barbuda  NY.ADJ.AEDU.CD
# 2         BHS            Bahamas  NY.ADJ.AEDU.CD
# 3         BLZ             Belice  NY.ADJ.AEDU.CD
# 4         BOL            Bolivia  NY.ADJ.AEDU.CD
#
#                                         Nombre_Serie          1992  \
# 0  Ahorro ajustado: Gasto en educación (US$ a pre...  6.960448e+09
# 1  Ahorro ajustado: Gasto en educación (US$ a pre...  1.735094e+07
# 2  Ahorro ajustado: Gasto en educación (US$ a pre...  1.160806e+08
# 3  Ahorro ajustado: Gasto en educación (US$ a pre...  2.849910e+07
# 4  Ahorro ajustado: Gasto en educación (US$ a pre...  1.921598e+08
#
#            1993          1994          1995          1996          1997  ...  \
# 0  8.414772e+09  1.040347e+10  8.795160e+09  9.332670e+09  9.105303e+09  ...
# 1  1.892571e+07  2.079647e+07  2.033655e+07  2.244582e+07  2.432835e+07  ...
# ...

# %%
df_gasto_educacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          34 non-null     float64
#  5   1993          34 non-null     float64
#  6   1994          34 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
for i in range(len(df_gasto_educacion)):
    minimo = df_gasto_educacion.iloc[i, 4:].min(axis=0)
    df_gasto_educacion.iloc[i] = df_gasto_educacion.iloc[i].fillna(minimo)

# %%
df_nivel_educativo.head()
# Out:
#   Codigo_Pais        Nombre_Pais       Codigo_Serie  \
# 0         ARG          Argentina  SE.TER.CUAT.BA.ZS
# 1         ATG  Antigua y Barbuda  SE.TER.CUAT.BA.ZS
# 2         BHS            Bahamas  SE.TER.CUAT.BA.ZS
# 3         BLZ             Belice  SE.TER.CUAT.BA.ZS
# 4         BOL            Bolivia  SE.TER.CUAT.BA.ZS
#
#                                         Nombre_Serie  1970  1981     2000  \
# 0  Nivel educativo, al menos secundaria superior ...   NaN   NaN      NaN
# 1  Nivel educativo, al menos secundaria superior ...   NaN   NaN      NaN
# 2  Nivel educativo, al menos secundaria superior ...   NaN   NaN  0.34115
# 3  Nivel educativo, al menos secundaria superior ...   NaN   NaN      NaN
# 4  Nivel educativo, al menos secundaria superior ...   NaN   NaN      NaN
#
#    2001  2002  2007  ...  2012  2013  2014       2015  2016  2017  2018  \
# 0   NaN   NaN   NaN  ...   NaN   NaN   NaN        NaN   NaN   NaN   NaN
# ...

# %%
df_nivel_educativo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1970          1 non-null      float64
#  5   1981          1 non-null      float64
#  6   2000          2 non-null      float64
#  7   2001          1 non-null      float64
#  8   2002          1 non-null      float64
#  9   2007          3 non-null      float64
#  10  2008          3 non-null      float64
#  11  2009          3 non-null      float64
#  12  2010          6 non-null      float64
#  13  2011          7 non-null      float64
#  14  2012          7 non-null      float64
#  15  2013          9 non-null      float64
#  16  2014          9 non-null      float64
# ...

# %%
df_pib.head()
# Out:
#   Codigo_Pais        Nombre_Pais    Codigo_Serie Nombre_Serie          1992  \
# 0         ARG          Argentina  NY.GDP.MKTP.CD          PIB  2.287886e+11
# 1         ATG  Antigua y Barbuda  NY.GDP.MKTP.CD          PIB  4.992815e+08
# 2         BHS            Bahamas  NY.GDP.MKTP.CD          PIB  3.109000e+09
# 3         BLZ             Belice  NY.GDP.MKTP.CD          PIB  6.935000e+08
# 4         BOL            Bolivia  NY.GDP.MKTP.CD          PIB  5.643893e+09
#
#            1993          1994          1995          1996          1997  ...  \
# 0  2.367417e+11  2.574400e+11  2.580318e+11  2.721498e+11  2.928590e+11  ...
# 1  5.351741e+08  5.894296e+08  5.772815e+08  6.337296e+08  6.806185e+08  ...
# 2  3.092000e+09  3.259000e+09  3.429000e+09  3.609000e+09  6.332360e+09  ...
# 3  7.510000e+08  7.715000e+08  8.185000e+08  8.515000e+08  8.680000e+08  ...
# 4  5.734677e+09  5.981245e+09  6.715220e+09  7.396967e+09  7.925673e+09  ...
#
# ...

# %%
df_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          35 non-null     float64
#  5   1993          35 non-null     float64
#  6   1994          35 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
for i in range(len(df_pib)):  # Imputamos los valores faltantes en df_pib con el valor mínimo para cada país
    minimo = df_pib.iloc[i, 4:].min(axis=0)
    df_pib.iloc[i] = df_pib.iloc[i].fillna(minimo)

# %%
df_tasa_nacimientos.head()
# Out:
#   Codigo_Pais        Nombre_Pais    Codigo_Serie         Nombre_Serie    1992  \
# 0         ARG          Argentina  SP.DYN.CBRT.IN  Tasa de nacimientos  21.683
# 1         ATG  Antigua y Barbuda  SP.DYN.CBRT.IN  Tasa de nacimientos  19.228
# 2         BHS            Bahamas  SP.DYN.CBRT.IN  Tasa de nacimientos  26.442
# 3         BLZ             Belice  SP.DYN.CBRT.IN  Tasa de nacimientos  34.308
# 4         BOL            Bolivia  SP.DYN.CBRT.IN  Tasa de nacimientos  34.645
#
#      1993    1994    1995    1996    1997  ...    2012    2013    2014  \
# 0  21.570  21.419  20.974  20.449  19.985  ...  17.729  17.632  17.504
# 1  18.597  18.990  19.847  20.823  20.118  ...  13.497  12.469  12.325
# 2  25.605  23.086  23.025  21.473  21.569  ...  14.114  12.244  13.570
# 3  33.519  32.322  32.256  31.624  31.787  ...  22.430  22.335  22.097
# 4  33.910  33.084  32.406  31.875  31.126  ...  24.934  24.541  24.140
#
#      2015    2016    2017    2018    2019    2020    2021
# ...

# %%
df_tasa_nacimientos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          35 non-null     float64
#  5   1993          35 non-null     float64
#  6   1994          35 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
df_tasa_mortalidad.head()
# Out:
#   Codigo_Pais        Nombre_Pais    Codigo_Serie               Nombre_Serie  \
# 0         ARG          Argentina  SP.DYN.CDRT.IN  Tasa de mortalidad, cruda
# 1         ATG  Antigua y Barbuda  SP.DYN.CDRT.IN  Tasa de mortalidad, cruda
# 2         BHS            Bahamas  SP.DYN.CDRT.IN  Tasa de mortalidad, cruda
# 3         BLZ             Belice  SP.DYN.CDRT.IN  Tasa de mortalidad, cruda
# 4         BOL            Bolivia  SP.DYN.CDRT.IN  Tasa de mortalidad, cruda
#
#      1992    1993    1994    1995    1996    1997  ...   2012   2013   2014  \
# 0   7.595   7.631   7.403   7.535   7.541   7.778  ...  7.394  7.494  7.447
# 1   7.745   7.666   7.533   7.416   7.257   7.104  ...  5.585  5.565  5.544
# 2   5.799   5.861   5.814   5.910   5.985   5.908  ...  6.491  6.490  6.483
# 3   5.718   5.599   5.362   5.448   5.420   5.631  ...  4.457  4.388  4.584
# 4  11.191  10.736  10.689  10.625  10.525  10.329  ...  7.433  7.306  7.262
#
#     2015   2016   2017   2018   2019   2020   2021
# ...

# %%
df_tasa_mortalidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          35 non-null     float64
#  5   1993          35 non-null     float64
#  6   1994          35 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
df_tasa_mortalidad_infantil.head()
# Out:
#   Codigo_Pais        Nombre_Pais    Codigo_Serie  \
# 0         ARG          Argentina  SP.DYN.IMRT.IN
# 1         ATG  Antigua y Barbuda  SP.DYN.IMRT.IN
# 2         BHS            Bahamas  SP.DYN.IMRT.IN
# 3         BLZ             Belice  SP.DYN.IMRT.IN
# 4         BOL            Bolivia  SP.DYN.IMRT.IN
#
#                                         Nombre_Serie  1992  1993  1994  1995  \
# 0  Tasa de mortalidad infantil (por 1000 nacimien...  24.4  23.5  22.6  21.6
# 1  Tasa de mortalidad infantil (por 1000 nacimien...  11.7  12.0  12.4  12.6
# 2  Tasa de mortalidad infantil (por 1000 nacimien...  18.2  17.4  16.6  15.8
# 3  Tasa de mortalidad infantil (por 1000 nacimien...  28.0  26.6  25.3  24.2
# 4  Tasa de mortalidad infantil (por 1000 nacimien...  78.3  75.5  72.8  70.0
#
#    1996  1997  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0  20.7  19.8  ...  11.9  11.4  10.9  10.3   9.8   9.1   8.4   7.6   6.8   6.1
# ...

# %%
df_tasa_mortalidad_infantil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   35 non-null     object
#  1   Nombre_Pais   35 non-null     object
#  2   Codigo_Serie  35 non-null     object
#  3   Nombre_Serie  35 non-null     object
#  4   1992          35 non-null     float64
#  5   1993          35 non-null     float64
#  6   1994          35 non-null     float64
#  7   1995          35 non-null     float64
#  8   1996          35 non-null     float64
#  9   1997          35 non-null     float64
#  10  1998          35 non-null     float64
#  11  1999          35 non-null     float64
#  12  2000          35 non-null     float64
#  13  2001          35 non-null     float64
#  14  2002          35 non-null     float64
#  15  2003          35 non-null     float64
#  16  2004          35 non-null     float64
# ...

# %%
n = len(df_esperanza_mujeres.columns)
df_esperanza_mujeres = pd.melt(df_esperanza_mujeres, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_esperanza_mujeres.columns[i] for i in range(4,n)], var_name = 'Año')
df_esperanza_mujeres
# Out:
#      Codigo_Pais                   Nombre_Pais       Codigo_Serie  \
# 0            ARG                     Argentina  SP.DYN.LE00.FE.IN
# 1            ATG             Antigua y Barbuda  SP.DYN.LE00.FE.IN
# 2            BHS                       Bahamas  SP.DYN.LE00.FE.IN
# 3            BLZ                        Belice  SP.DYN.LE00.FE.IN
# 4            BOL                       Bolivia  SP.DYN.LE00.FE.IN
# ...          ...                           ...                ...
# 1045         TTO             Trinidad y Tobago  SP.DYN.LE00.FE.IN
# 1046         URY                       Uruguay  SP.DYN.LE00.FE.IN
# 1047         USA     Estados Unidos de América  SP.DYN.LE00.FE.IN
# 1048         VCT  San Vicente y las Granadinas  SP.DYN.LE00.FE.IN
# 1049         VEN                     Venezuela  SP.DYN.LE00.FE.IN
#
#                                     Nombre_Serie   Año   value
# 0     Esperanza de vida al nacer, mujeres (años)  1992  75.719
# ...

# %%
n = len(df_esperanza_hombres.columns)
df_esperanza_hombres = pd.melt(df_esperanza_hombres, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_esperanza_hombres.columns[i] for i in range(4,n)], var_name = 'Año')
df_esperanza_hombres
# Out:
#      Codigo_Pais                   Nombre_Pais       Codigo_Serie  \
# 0            ARG                     Argentina  SP.DYN.LE00.MA.IN
# 1            ATG             Antigua y Barbuda  SP.DYN.LE00.MA.IN
# 2            BHS                       Bahamas  SP.DYN.LE00.MA.IN
# 3            BLZ                        Belice  SP.DYN.LE00.MA.IN
# 4            BOL                       Bolivia  SP.DYN.LE00.MA.IN
# ...          ...                           ...                ...
# 1045         TTO             Trinidad y Tobago  SP.DYN.LE00.MA.IN
# 1046         URY                       Uruguay  SP.DYN.LE00.MA.IN
# 1047         USA     Estados Unidos de América  SP.DYN.LE00.MA.IN
# 1048         VCT  San Vicente y las Granadinas  SP.DYN.LE00.MA.IN
# 1049         VEN                     Venezuela  SP.DYN.LE00.MA.IN
#
#                                     Nombre_Serie   Año   value
# 0     Esperanza de vida al nacer, hombres (años)  1992  69.095
# ...

# %%
n = len(df_esperanza_general.columns)
df_esperanza_general = pd.melt(df_esperanza_general, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_esperanza_general.columns[i] for i in range(4,n)], var_name = 'Año')
df_esperanza_general
# Out:
#      Codigo_Pais                   Nombre_Pais    Codigo_Serie  \
# 0            ARG                     Argentina  SP.DYN.LE00.IN
# 1            ATG             Antigua y Barbuda  SP.DYN.LE00.IN
# 2            BHS                       Bahamas  SP.DYN.LE00.IN
# 3            BLZ                        Belice  SP.DYN.LE00.IN
# 4            BOL                       Bolivia  SP.DYN.LE00.IN
# ...          ...                           ...             ...
# 1045         TTO             Trinidad y Tobago  SP.DYN.LE00.IN
# 1046         URY                       Uruguay  SP.DYN.LE00.IN
# 1047         USA     Estados Unidos de América  SP.DYN.LE00.IN
# 1048         VCT  San Vicente y las Granadinas  SP.DYN.LE00.IN
# 1049         VEN                     Venezuela  SP.DYN.LE00.IN
#
#                                   Nombre_Serie   Año      value
# 0     Esperanza de vida al nacer, total (años)  1992  72.430000
# 1     Esperanza de vida al nacer, total (años)  1992  73.417000
# ...

# %%
n = len(df_cobertura_servicios.columns)
df_cobertura_servicios = pd.melt(df_cobertura_servicios, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_cobertura_servicios.columns[i] for i in range(4,n)], var_name = 'Año')
df_cobertura_servicios
# Out:
#     Codigo_Pais                   Nombre_Pais       Codigo_Serie  \
# 0           ARG                     Argentina  SH.UHC.SRVS.CV.XD
# 1           ATG             Antigua y Barbuda  SH.UHC.SRVS.CV.XD
# 2           BHS                       Bahamas  SH.UHC.SRVS.CV.XD
# 3           BLZ                        Belice  SH.UHC.SRVS.CV.XD
# 4           BOL                       Bolivia  SH.UHC.SRVS.CV.XD
# ..          ...                           ...                ...
# 205         TTO             Trinidad y Tobago  SH.UHC.SRVS.CV.XD
# 206         URY                       Uruguay  SH.UHC.SRVS.CV.XD
# 207         USA     Estados Unidos de América  SH.UHC.SRVS.CV.XD
# 208         VCT  San Vicente y las Granadinas  SH.UHC.SRVS.CV.XD
# 209         VEN                     Venezuela  SH.UHC.SRVS.CV.XD
#
#                              Nombre_Serie   Año  value
# 0    Índice de cobertura de servicios UHC  2000   68.0
# 1    Índice de cobertura de servicios UHC  2000   43.0
# ...

# %%
n = len(df_gastos_salud.columns)
df_gastos_salud = pd.melt(df_gastos_salud, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_gastos_salud.columns[i] for i in range(4,n)], var_name = 'Año')
df_gastos_salud
# Out:
#     Codigo_Pais                   Nombre_Pais       Codigo_Serie  \
# 0           ARG                     Argentina  SH.XPD.CHEX.PC.CD
# 1           ATG             Antigua y Barbuda  SH.XPD.CHEX.PC.CD
# 2           BHS                       Bahamas  SH.XPD.CHEX.PC.CD
# 3           BLZ                        Belice  SH.XPD.CHEX.PC.CD
# 4           BOL                       Bolivia  SH.XPD.CHEX.PC.CD
# ..          ...                           ...                ...
# 765         TTO             Trinidad y Tobago  SH.XPD.CHEX.PC.CD
# 766         URY                       Uruguay  SH.XPD.CHEX.PC.CD
# 767         USA     Estados Unidos de América  SH.XPD.CHEX.PC.CD
# 768         VCT  San Vicente y las Granadinas  SH.XPD.CHEX.PC.CD
# 769         VEN                     Venezuela  SH.XPD.CHEX.PC.CD
#
#                                           Nombre_Serie   Año       value
# 0    Gasto corriente en salud per cápita (US$ corri...  2000  704.945923
# ...

# %%
n = len(df_indice_gini.columns)
df_indice_gini = pd.melt(df_indice_gini, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_indice_gini.columns[i] for i in range(4,n)], var_name = 'Año')
df_indice_gini
# Out:
#      Codigo_Pais                   Nombre_Pais Codigo_Serie    Nombre_Serie  \
# 0            ARG                     Argentina  SI.POV.GINI  Índice de Gini
# 1            ATG             Antigua y Barbuda  SI.POV.GINI  Índice de Gini
# 2            BHS                       Bahamas  SI.POV.GINI  Índice de Gini
# 3            BLZ                        Belice  SI.POV.GINI  Índice de Gini
# 4            BOL                       Bolivia  SI.POV.GINI  Índice de Gini
# ...          ...                           ...          ...             ...
# 1045         TTO             Trinidad y Tobago  SI.POV.GINI  Índice de Gini
# 1046         URY                       Uruguay  SI.POV.GINI  Índice de Gini
# 1047         USA     Estados Unidos de América  SI.POV.GINI  Índice de Gini
# 1048         VCT  San Vicente y las Granadinas  SI.POV.GINI  Índice de Gini
# 1049         VEN                     Venezuela  SI.POV.GINI  Índice de Gini
#
#        Año  value
# 0     1992   45.5
# ...

# %%
n = len(df_personas_debajo_50.columns)
df_personas_debajo_50 = pd.melt(df_personas_debajo_50, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_personas_debajo_50.columns[i] for i in range(4,n)], var_name = 'Año')
df_personas_debajo_50
# Out:
#      Codigo_Pais                   Nombre_Pais Codigo_Serie  \
# 0            ARG                     Argentina  SI.DST.50MD
# 1            ATG             Antigua y Barbuda  SI.DST.50MD
# 2            BHS                       Bahamas  SI.DST.50MD
# 3            BLZ                        Belice  SI.DST.50MD
# 4            BOL                       Bolivia  SI.DST.50MD
# ...          ...                           ...          ...
# 1045         TTO             Trinidad y Tobago  SI.DST.50MD
# 1046         URY                       Uruguay  SI.DST.50MD
# 1047         USA     Estados Unidos de América  SI.DST.50MD
# 1048         VCT  San Vicente y las Granadinas  SI.DST.50MD
# 1049         VEN                     Venezuela  SI.DST.50MD
#
#                                            Nombre_Serie   Año  value
# 0     Proporción de personas que viven por debajo de...  1992   19.6
# 1     Proporción de personas que viven por debajo de...  1992    NaN
# ...

# %%
n = len(df_pobreza_multidimensional.columns)
df_pobreza_multidimensional = pd.melt(df_pobreza_multidimensional, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_pobreza_multidimensional.columns[i] for i in range(4,n)], var_name = 'Año')
df_pobreza_multidimensional
# Out:
#     Codigo_Pais                   Nombre_Pais Codigo_Serie  \
# 0           ARG                     Argentina  SI.POV.MDIM
# 1           ATG             Antigua y Barbuda  SI.POV.MDIM
# 2           BHS                       Bahamas  SI.POV.MDIM
# 3           BLZ                        Belice  SI.POV.MDIM
# 4           BOL                       Bolivia  SI.POV.MDIM
# ..          ...                           ...          ...
# 450         TTO             Trinidad y Tobago  SI.POV.MDIM
# 451         URY                       Uruguay  SI.POV.MDIM
# 452         USA     Estados Unidos de América  SI.POV.MDIM
# 453         VCT  San Vicente y las Granadinas  SI.POV.MDIM
# 454         VEN                     Venezuela  SI.POV.MDIM
#
#                                           Nombre_Serie   Año  value
# 0    Tasa de recuento de la pobreza multidimensiona...  2010    NaN
# 1    Tasa de recuento de la pobreza multidimensiona...  2010    NaN
# ...

# %%
n = len(df_homicidios.columns)
df_homicidios = pd.melt(df_homicidios, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_homicidios.columns[i] for i in range(4,n)], var_name = 'Año')
df_homicidios
# Out:
#      Codigo_Pais                   Nombre_Pais    Codigo_Serie  \
# 0            ARG                     Argentina  VC.IHR.PSRC.P5
# 1            ATG             Antigua y Barbuda  VC.IHR.PSRC.P5
# 2            BHS                       Bahamas  VC.IHR.PSRC.P5
# 3            BLZ                        Belice  VC.IHR.PSRC.P5
# 4            BOL                       Bolivia  VC.IHR.PSRC.P5
# ...          ...                           ...             ...
# 1045         TTO             Trinidad y Tobago  VC.IHR.PSRC.P5
# 1046         URY                       Uruguay  VC.IHR.PSRC.P5
# 1047         USA     Estados Unidos de América  VC.IHR.PSRC.P5
# 1048         VCT  San Vicente y las Granadinas  VC.IHR.PSRC.P5
# 1049         VEN                     Venezuela  VC.IHR.PSRC.P5
#
#                                           Nombre_Serie   Año      value
# 0     Homicidios dolosos (por cada 100.000 habitantes)  1992   4.622679
# ...

# %%
n = len(df_desempleo.columns)
df_desempleo = pd.melt(df_desempleo, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_desempleo.columns[i] for i in range(4,n)], var_name = 'Año')
df_desempleo
# Out:
#      Codigo_Pais                   Nombre_Pais    Codigo_Serie  \
# 0            ARG                     Argentina  SL.UEM.TOTL.ZS
# 1            ATG             Antigua y Barbuda  SL.UEM.TOTL.ZS
# 2            BHS                       Bahamas  SL.UEM.TOTL.ZS
# 3            BLZ                        Belice  SL.UEM.TOTL.ZS
# 4            BOL                       Bolivia  SL.UEM.TOTL.ZS
# ...          ...                           ...             ...
# 1045         TTO             Trinidad y Tobago  SL.UEM.TOTL.ZS
# 1046         URY                       Uruguay  SL.UEM.TOTL.ZS
# 1047         USA     Estados Unidos de América  SL.UEM.TOTL.ZS
# 1048         VCT  San Vicente y las Granadinas  SL.UEM.TOTL.ZS
# 1049         VEN                     Venezuela  SL.UEM.TOTL.ZS
#
#                                            Nombre_Serie   Año   value
# 0     Desempleo, total (% de la población activa tot...  1992   6.360
# ...

# %%
n = len(df_gasto_educacion.columns)
df_gasto_educacion = pd.melt(df_gasto_educacion, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_gasto_educacion.columns[i] for i in range(4,n)], var_name = 'Año')
df_gasto_educacion
# Out:
#      Codigo_Pais                   Nombre_Pais    Codigo_Serie  \
# 0            ARG                     Argentina  NY.ADJ.AEDU.CD
# 1            ATG             Antigua y Barbuda  NY.ADJ.AEDU.CD
# 2            BHS                       Bahamas  NY.ADJ.AEDU.CD
# 3            BLZ                        Belice  NY.ADJ.AEDU.CD
# 4            BOL                       Bolivia  NY.ADJ.AEDU.CD
# ...          ...                           ...             ...
# 1045         TTO             Trinidad y Tobago  NY.ADJ.AEDU.CD
# 1046         URY                       Uruguay  NY.ADJ.AEDU.CD
# 1047         USA     Estados Unidos de América  NY.ADJ.AEDU.CD
# 1048         VCT  San Vicente y las Granadinas  NY.ADJ.AEDU.CD
# 1049         VEN                     Venezuela  NY.ADJ.AEDU.CD
#
#                                            Nombre_Serie   Año         value
# 0     Ahorro ajustado: Gasto en educación (US$ a pre...  1992  6.960448e+09
# ...

# %%
n = len(df_nivel_educativo.columns)
df_nivel_educativo = pd.melt(df_nivel_educativo, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_nivel_educativo.columns[i] for i in range(4,n)], var_name = 'Año')
df_nivel_educativo
# Out:
#     Codigo_Pais                   Nombre_Pais       Codigo_Serie  \
# 0           ARG                     Argentina  SE.TER.CUAT.BA.ZS
# 1           ATG             Antigua y Barbuda  SE.TER.CUAT.BA.ZS
# 2           BHS                       Bahamas  SE.TER.CUAT.BA.ZS
# 3           BLZ                        Belice  SE.TER.CUAT.BA.ZS
# 4           BOL                       Bolivia  SE.TER.CUAT.BA.ZS
# ..          ...                           ...                ...
# 695         TTO             Trinidad y Tobago  SE.TER.CUAT.BA.ZS
# 696         URY                       Uruguay  SE.TER.CUAT.BA.ZS
# 697         USA     Estados Unidos de América  SE.TER.CUAT.BA.ZS
# 698         VCT  San Vicente y las Granadinas  SE.TER.CUAT.BA.ZS
# 699         VEN                     Venezuela  SE.TER.CUAT.BA.ZS
#
#                                           Nombre_Serie   Año  value
# 0    Nivel educativo, al menos secundaria superior ...  1970    NaN
# ...

# %%
n = len(df_pib.columns)
df_pib = pd.melt(df_pib, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_pib.columns[i] for i in range(4,n)], var_name = 'Año')
df_pib
# Out:
#      Codigo_Pais                   Nombre_Pais    Codigo_Serie Nombre_Serie  \
# 0            ARG                     Argentina  NY.GDP.MKTP.CD          PIB
# 1            ATG             Antigua y Barbuda  NY.GDP.MKTP.CD          PIB
# 2            BHS                       Bahamas  NY.GDP.MKTP.CD          PIB
# 3            BLZ                        Belice  NY.GDP.MKTP.CD          PIB
# 4            BOL                       Bolivia  NY.GDP.MKTP.CD          PIB
# ...          ...                           ...             ...          ...
# 1045         TTO             Trinidad y Tobago  NY.GDP.MKTP.CD          PIB
# 1046         URY                       Uruguay  NY.GDP.MKTP.CD          PIB
# 1047         USA     Estados Unidos de América  NY.GDP.MKTP.CD          PIB
# 1048         VCT  San Vicente y las Granadinas  NY.GDP.MKTP.CD          PIB
# 1049         VEN                     Venezuela  NY.GDP.MKTP.CD          PIB
#
#        Año         value
# 0     1992  2.287886e+11
# ...

# %%
n = len(df_tasa_nacimientos.columns)
df_tasa_nacimientos = pd.melt(df_tasa_nacimientos, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_tasa_nacimientos.columns[i] for i in range(4,n)], var_name = 'Año')
df_tasa_nacimientos
# Out:
#      Codigo_Pais                   Nombre_Pais    Codigo_Serie  \
# 0            ARG                     Argentina  SP.DYN.CBRT.IN
# 1            ATG             Antigua y Barbuda  SP.DYN.CBRT.IN
# 2            BHS                       Bahamas  SP.DYN.CBRT.IN
# 3            BLZ                        Belice  SP.DYN.CBRT.IN
# 4            BOL                       Bolivia  SP.DYN.CBRT.IN
# ...          ...                           ...             ...
# 1045         TTO             Trinidad y Tobago  SP.DYN.CBRT.IN
# 1046         URY                       Uruguay  SP.DYN.CBRT.IN
# 1047         USA     Estados Unidos de América  SP.DYN.CBRT.IN
# 1048         VCT  San Vicente y las Granadinas  SP.DYN.CBRT.IN
# 1049         VEN                     Venezuela  SP.DYN.CBRT.IN
#
#              Nombre_Serie   Año   value
# 0     Tasa de nacimientos  1992  21.683
# 1     Tasa de nacimientos  1992  19.228
# 2     Tasa de nacimientos  1992  26.442
# 3     Tasa de nacimientos  1992  34.308
# ...

# %%
n = len(df_tasa_mortalidad.columns)
df_tasa_mortalidad = pd.melt(df_tasa_mortalidad, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_tasa_mortalidad.columns[i] for i in range(4,n)], var_name = 'Año')
df_tasa_mortalidad
# Out:
#      Codigo_Pais                   Nombre_Pais    Codigo_Serie  \
# 0            ARG                     Argentina  SP.DYN.CDRT.IN
# 1            ATG             Antigua y Barbuda  SP.DYN.CDRT.IN
# 2            BHS                       Bahamas  SP.DYN.CDRT.IN
# 3            BLZ                        Belice  SP.DYN.CDRT.IN
# 4            BOL                       Bolivia  SP.DYN.CDRT.IN
# ...          ...                           ...             ...
# 1045         TTO             Trinidad y Tobago  SP.DYN.CDRT.IN
# 1046         URY                       Uruguay  SP.DYN.CDRT.IN
# 1047         USA     Estados Unidos de América  SP.DYN.CDRT.IN
# 1048         VCT  San Vicente y las Granadinas  SP.DYN.CDRT.IN
# 1049         VEN                     Venezuela  SP.DYN.CDRT.IN
#
#                    Nombre_Serie   Año   value
# 0     Tasa de mortalidad, cruda  1992   7.595
# 1     Tasa de mortalidad, cruda  1992   7.745
# 2     Tasa de mortalidad, cruda  1992   5.799
# ...

# %%
n = len(df_tasa_mortalidad_infantil.columns)
df_tasa_mortalidad_infantil = pd.melt(df_tasa_mortalidad_infantil, id_vars=['Codigo_Pais', 'Nombre_Pais', 'Codigo_Serie', 'Nombre_Serie'], value_vars=[df_tasa_mortalidad_infantil.columns[i] for i in range(4,n)], var_name = 'Año')
df_tasa_mortalidad_infantil
# Out:
#      Codigo_Pais                   Nombre_Pais    Codigo_Serie  \
# 0            ARG                     Argentina  SP.DYN.IMRT.IN
# 1            ATG             Antigua y Barbuda  SP.DYN.IMRT.IN
# 2            BHS                       Bahamas  SP.DYN.IMRT.IN
# 3            BLZ                        Belice  SP.DYN.IMRT.IN
# 4            BOL                       Bolivia  SP.DYN.IMRT.IN
# ...          ...                           ...             ...
# 1045         TTO             Trinidad y Tobago  SP.DYN.IMRT.IN
# 1046         URY                       Uruguay  SP.DYN.IMRT.IN
# 1047         USA     Estados Unidos de América  SP.DYN.IMRT.IN
# 1048         VCT  San Vicente y las Granadinas  SP.DYN.IMRT.IN
# 1049         VEN                     Venezuela  SP.DYN.IMRT.IN
#
#                                            Nombre_Serie   Año  value
# 0     Tasa de mortalidad infantil (por 1000 nacimien...  1992   24.4
# 1     Tasa de mortalidad infantil (por 1000 nacimien...  1992   11.7
# ...

# %%
df_esperanza_mujeres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_esperanza_hombres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_esperanza_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_cobertura_servicios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   210 non-null    object
#  1   Nombre_Pais   210 non-null    object
#  2   Codigo_Serie  210 non-null    object
#  3   Nombre_Serie  210 non-null    object
#  4   Año           210 non-null    object
#  5   value         210 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 10.0+ KB

# %%
df_gastos_salud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 770 entries, 0 to 769
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   770 non-null    object
#  1   Nombre_Pais   770 non-null    object
#  2   Codigo_Serie  770 non-null    object
#  3   Nombre_Serie  770 non-null    object
#  4   Año           770 non-null    object
#  5   value         738 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 36.2+ KB

# %%
df_indice_gini.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         428 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_personas_debajo_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         438 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_pobreza_multidimensional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 455 entries, 0 to 454
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   455 non-null    object
#  1   Nombre_Pais   455 non-null    object
#  2   Codigo_Serie  455 non-null    object
#  3   Nombre_Serie  455 non-null    object
#  4   Año           455 non-null    object
#  5   value         67 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 21.5+ KB

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_desempleo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_gasto_educacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_nivel_educativo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   700 non-null    object
#  1   Nombre_Pais   700 non-null    object
#  2   Codigo_Serie  700 non-null    object
#  3   Nombre_Serie  700 non-null    object
#  4   Año           700 non-null    object
#  5   value         109 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 32.9+ KB

# %%
df_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_tasa_nacimientos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_tasa_mortalidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
df_tasa_mortalidad_infantil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo_Pais   1050 non-null   object
#  1   Nombre_Pais   1050 non-null   object
#  2   Codigo_Serie  1050 non-null   object
#  3   Nombre_Serie  1050 non-null   object
#  4   Año           1050 non-null   object
#  5   value         1050 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 49.3+ KB

# %%
# DataSets a considerar en el proyecto:
df_esperanza_mujeres.to_csv("Esperanza_vida_mujeres.csv", index = False)
df_esperanza_hombres.to_csv("Esperanza_vida_hombres.csv", index = False)
df_esperanza_general.to_csv("Esperanza_vida_general.csv", index = False)
df_homicidios.to_csv("Homicidios.csv", index = False)
df_desempleo.to_csv("Desempleo.csv", index = False)
df_gasto_educacion.to_csv("Gasto_educacion.csv", index = False)
df_pib.to_csv("PIB.csv", index = False)
df_tasa_nacimientos.to_csv("Tasa_nacimientos.csv", index = False)
df_tasa_mortalidad.to_csv("Tasa_mortalidad.csv", index = False)
df_tasa_mortalidad_infantil.to_csv("Tasa_mortalidad_infantil.csv", index = False)
